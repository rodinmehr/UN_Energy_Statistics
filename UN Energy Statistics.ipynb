# %% [markdown]
# 1. At a global level and focusing only on “wind” and “solar” energy production, what trends can you observe? Specifically —
#
#         a. Are there any countries that are adopting these renewable energy sources more aggressively than others?
#
#         b. If you were asked to group/cluster countries by their use/adoption of “wind” and “solar” vs any other forms of energy they use (i.e. to present a global energy mix by country), how would you do it? What machine learning techniques would you use, with which data, and why?

# %% [markdown]
# # Defining API parameters

# %%
countries = {
    "Afghanistan": "004",
    "Albania": "008",
    "Algeria": "012",
    "American Samoa": "016",
    "Andorra": "020",
    "Angola": "024",
    "Antigua and Barbuda": "028",
    "Azerbaijan": "031",
    "Argentina": "032",
    "Australia": "036",
    "Austria": "040",
    "Bahamas": "044",
    "Bahrain": "048",
    "Bangladesh": "050",
    "Armenia": "051",
    "Barbados": "052",
    "Belgium": "056",
    "Bermuda": "060",
    "Bhutan": "064",
    "Bolivia": "068",
    "Bosnia and Herzegovina": "070",
    "Botswana": "072",
    "Brazil": "076",
    "Antarctic Fisheries": "081",
    "Belize": "084",
    "Solomon Islands": "090",
    "British Virgin Islands": "092",
    "Brunei Darussalam": "096",
    "Bulgaria": "100",
    "Myanmar": "104",
    "Burundi": "108",
    "Belarus": "112",
    "Cambodia": "116",
    "Cameroon": "120",
    "Canada": "124",
    "Cabo Verde": "132",
    "Cayman Islands": "136",
    "Central African Republic": "140",
    "Sri Lanka": "144",
    "Chad": "148",
    "Chile": "152",
    "China": "156",
    "Other Asia": "158",
    "Colombia": "170",
    "Comoros": "174",
    "Mayotte": "175",
    "Congo": "178",
    "Democratic Republic of the Congo": "180",
    "Cook Islands": "184",
    "Costa Rica": "188",
    "Croatia": "191",
    "Cuba": "192",
    "Cyprus": "196",
    "Czechoslovakia [former]": "200",
    "Czech Republic": "203",
    "Benin": "204",
    "Denmark": "208",
    "Dominica": "212",
    "Dominican Republic": "214",
    "Ecuador": "218",
    "El Salvador": "222",
    "Equatorial Guinea": "226",
    "Ethiopia [up to 1993]": "230",
    "Ethiopia [from 1993]": "231",
    "Eritrea": "232",
    "Estonia": "233",
    "Faeroe Islands": "234",
    "Falkland Islands (Malvinas)": "238",
    "Fiji": "242",
    "Finland": "246",
    "France incl. Monaco": "251",
    "French Guiana": "254",
    "French Polynesia": "258",
    "Djibouti": "262",
    "Gabon": "266",
    "Georgia": "268",
    "Gambia": "270",
    "State of Palestine": "275",
    "Germany": "276",
    "German Democratic Republic [former]": "278",
    "Germany, Federal Republic of": "280",
    "Ghana": "288",
    "Gibraltar": "292",
    "Kiribati": "296",
    "Greece": "300",
    "Greenland": "304",
    "Grenada": "308",
    "Guadeloupe": "312",
    "Guam": "316",
    "Guatemala": "320",
    "Guinea": "324",
    "Guyana": "328",
    "Haiti": "332",
    "Honduras": "340",
    "China, Hong Kong Special Administrative Region": "344",
    "Hungary": "348",
    "Iceland": "352",
    "India": "356",
    "Indonesia": "360",
    "Iran (Islamic Republic of)": "364",
    "Iraq": "368",
    "Ireland": "372",
    "Israel": "376",
    "Italy and San Marino": "382",
    "Cote d'Ivoire": "384",
    "Jamaica": "388",
    "Japan": "392",
    "Kazakhstan": "398",
    "Jordan": "400",
    "Kenya": "404",
    "Democratic People's Republic of Korea": "408",
    "Republic of Korea": "410",
    "Kosovo": "412",
    "Kuwait": "414",
    "Kyrgyzstan": "417",
    "Lao People's Democratic Republic": "418",
    "Lebanon": "422",
    "Lesotho": "426",
    "Latvia": "428",
    "Liberia": "430",
    "Libya": "434",
    "Liechtenstein": "438",
    "Lithuania": "440",
    "Luxembourg": "442",
    "China, Macao Special Administrative Region": "446",
    "Madagascar": "450",
    "Malawi": "454",
    "Malaysia": "458",
    "Maldives": "462",
    "Mali": "466",
    "Malta": "470",
    "Martinique": "474",
    "Mauritania": "478",
    "Mauritius": "480",
    "Mexico": "484",
    "Mongolia": "496",
    "Republic of Moldova": "498",
    "Montenegro": "499",
    "Montserrat": "500",
    "Morocco": "504",
    "Mozambique": "508",
    "Oman": "512",
    "Namibia": "516",
    "Nauru": "520",
    "Nepal": "524",
    "Netherlands": "528",
    "Netherlands Antilles": "530",
    "Curaçao": "531",
    "Aruba": "533",
    "Sint Maarten (Dutch part)": "534",
    "Bonaire, Sint Eustatius and Saba": "535",
    "New Caledonia": "540",
    "Vanuatu": "548",
    "New Zealand": "554",
    "Nicaragua": "558",
    "Niger": "562",
    "Nigeria": "566",
    "Niue": "570",
    "Norway including Svalbard and Jan Mayen Islands": "579",
    "Northern Mariana Islands": "580",
    "Pacific Islands (Trust Territory)": "582",
    "Micronesia, Federated States of": "583",
    "Marshall Islands": "584",
    "Palau": "585",
    "Pakistan": "586",
    "Panama": "591",
    "Papua New Guinea": "598",
    "Paraguay": "600",
    "Peru": "604",
    "Philippines": "608",
    "Poland": "616",
    "Portugal": "620",
    "Guinea-Bissau": "624",
    "Timor-Leste": "626",
    "Puerto Rico": "630",
    "Qatar": "634",
    "Reunion": "638",
    "Romania": "642",
    "Russian Federation": "643",
    "Rwanda": "646",
    "Saint Helena": "654",
    "Saint Kitts and Nevis": "659",
    "Anguilla": "660",
    "Saint Lucia": "662",
    "Saint Pierre and Miquelon": "666",
    "Saint Vincent and the Grenadines": "670",
    "Sao Tome and Principe": "678",
    "Saudi Arabia": "682",
    "Senegal": "686",
    "Serbia": "688",
    "Seychelles": "690",
    "Sierra Leone": "694",
    "Singapore": "702",
    "Slovakia": "703",
    "Viet Nam": "704",
    "Slovenia": "705",
    "Somalia": "706",
    "South Africa": "710",
    "Zimbabwe": "716",
    "Democratic Yemen [former]": "720",
    "Spain": "724",
    "South Sudan": "728",
    "Sudan": "729",
    "Sudan [up to 2011]": "736",
    "Suriname": "740",
    "Eswatini": "748",
    "Sweden": "752",
    "Switzerland-Liechtenstein": "757",
    "Syrian Arab Republic": "760",
    "Tajikistan": "762",
    "Thailand": "764",
    "Togo": "768",
    "Tonga": "776",
    "Trinidad and Tobago": "780",
    "United Arab Emirates": "784",
    "Tunisia": "788",
    "Turkey": "792",
    "Turkmenistan": "795",
    "Turks and Caicos Islands": "796",
    "Tuvalu": "798",
    "Uganda": "800",
    "Ukraine": "804",
    "North Macedonia": "807",
    "Union of Soviet Socialist Republics [former]": "810",
    "Egypt": "818",
    "United Kingdom": "826",
    "Guernsey": "831",
    "Jersey": "832",
    "Isle of Man": "833",
    "United Republic of Tanzania": "834",
    "United States": "840",
    "United States Virgin Islands": "850",
    "Burkina Faso": "854",
    "Uruguay": "858",
    "Uzbekistan": "860",
    "Venezuela": "862",
    "Wallis and Futuna Islands": "876",
    "Samoa": "882",
    "Yemen Arab Republic [former]": "886",
    "Yemen": "887",
    "Yugoslavia [former Socialist Federal Republic]": "890",
    "Serbia and Montenegro": "891",
    "Zambia": "894",
}

Commodity = {
    "Hard Coal": "0100",
    "Coking coal": "0121",
    "Other bituminous coal": "0129",
    "Brown Coal": "0200",
    "Coke Oven Coke": "0311",
    "Patent fuel": "0320",
    "Coal Tar": "0340",
    "Coke Oven Gas": "0350",
    "Gasworks Gas": "0360",
    "Blast Furnace Gas": "0371",
    "Natural Gas (including LNG)": "3000",
    "Conventional crude oil": "4100",
    "Natural Gas Liquids": "4200",
    "Refinery Feedstocks": "4300",
    "Additives and Oxygenates": "4400",
    "Other hydrocarbons": "4500",
    "Refinery Gas": "4610",
    "Ethane": "4620",
    "Liquified Petroleum Gas": "4630",
    "Naphtha": "4640",
    "Aviation Gasoline": "4651",
    "Motor Gasoline": "4652",
    "Of which: biogasoline": "5212",
    "Kerosene-type Jet Fuel": "4661",
    "Other kerosene": "4669",
    "Gas Oil/ Diesel Oil": "4670",
    "Of which: biodiesel": "5222",
    "Fuel Oil": "4680",
    "White spirit and special boiling point industrial spirits": "4691",
    "Lubricants": "4692",
    "Paraffin waxes": "4693",
    "Petroleum Coke": "4694",
    "Bitumen": "4695",
    "Other oil products n.e.c.": "4699",
    "Fuelwood": "5110",
    "Animal waste": "5130",
    "Other Vegetal Material and Residues": "5150",
    "Biogasoline": "5210",
    "Biodiesel": "5220",
    "Biogases": "5300",
    "Industrial Waste": "6100",
    "Municipal Wastes": "6200",
    "Total Electricity": "7000",
    "Hydro": "7000H",
    "Nuclear Electricity": "7000N",
    "Tide, wave and ocean electricity": "7000O",
    "Solar Electricity": "7000S",
    "Thermal Electricity": "7000T",
    "Wind Electricity": "7000W",
    "Heat": "8000",
    "Heat from combustible fuels": "8000T",
    "Direct use of geothermal heat": "DG",
    "Direct use of solar thermal heat": "DS",
    "Electricity, net installed capacity of electric power plants": "EC",
    "Total Refinery Output": "GR",
    "Falling Water": "WF",
}

transaction = {
    "Production": "01",
    "Imports": "03",
    "Exports": "04",
    "Transformation": "08",
    "Transformation in coke ovens": "081",
    "Total energy supply": "GA",
    "Final consumption": "NA",
    "Final energy consumption": "12",
    "Consumption by manufacturing, construction and non-fuel industry": "121",
    "Consumption by other manuf., const. and non-fuel ind.": "1214",
    "Consumption by non-ferrous metals": "1214A",
    "Consumption by non-metallic minerals": "1214B",
    "Consumption not elsewhere specified (industry)": "1214O",
    "Consumption by other": "123",
    "Consumption by households": "1231",
    "Consumption by commerce and public services": "1235",
}

#time_period

# %% [markdown]
# # Getting data

# %%
import requests

api_url = "https://data.un.org/WS/rest/data/UNSD,DF_UNDATA_ENERGY,/."+ countries["United Kingdom"] +"."+ Commodity["Total Electricity"]  +"./?startPeriod=2015-01-01&format=jsondata"
response = requests.get(api_url)
response.json()
# Out:
# {'meta': {'schema': 'https://raw.githubusercontent.com/sdmx-twg/sdmx-json/develop/data-message/tools/schemas/1.0/sdmx-json-data-schema.json',
#   'id': 'IREFba7e455b5bad44d383fb8d7a4d7f16f7',
#   'prepared': '2023-12-19T01:29:46',
#   'test': True,
#   'content-languages': ['en'],
#   'sender': {'id': 'NOT_CONFIGURED', 'name': {'en': 'unknown'}}},
#  'data': {'dataSets': [{'action': 'Information',
#     'annotations': [0, 1, 2, 3],
#     'series': {'0:0:0:0': {'attributes': [0],
#       'annotations': [],
#       'observations': {'0': [339671, 0, 0],
#        '1': [339160, 0, 0],
#        '2': [337884.491, 0, 0],
#        '3': [333162.457, 0, 0],
#        '4': [323845.843, 0, 0],
#        '5': [311259.062, 0, 0]}},
#      '0:0:0:1': {'attributes': [0],
#       'annotations': [],
#       'observations': {'0': [178214, 0, 0],
#        '1': [176224, 0, 0],
#        '2': [161420.462, 0, 0],
#        '3': [152230.413, 0, 0],
#        '4': [140700.296, 0, 0],
# ...
